# %%
import shutil
import os

# %%
# duplicate the dataset 
source_dir = "/content/drive/MyDrive/chest_xray 2 classes split (all)/"
destination_dir = "/content/drive/MyDrive/chest_xray 3 classes split (all)/"
#shutil.copytree(source_dir, destination_dir)
# Out:
# '/content/drive/MyDrive/chest_xray 3 classes split (all)/'

# %%
#copy missing images
source_folder = "/content/drive/MyDrive/chest_xray 2 classes split (all)/Pneumonia/"
destination_folder = "/content/drive/MyDrive/chest_xray 3 classes split (all)/Pneumonia/"
cpt = 0
# fetch all files
for file_name in os.listdir(source_folder):
    # construct full file path
    source = source_folder + file_name
    destination = destination_folder + file_name
    # copy only files
    if file_name not  in os.listdir(destination_folder):
        #shutil.copy(source, destination)
        #cpt+=1
        print('moved', file_name)
        print(cpt)
# Out:
# moved person1502_bacteria_3929.jpeg
# 1
# moved person1346_bacteria_3430.jpeg
# 2
# moved person866_virus_1511.jpeg
# 3
# moved person1356_virus_2337.jpeg
# 4
# moved person19_bacteria_58.jpeg
# 5
# moved person1488_bacteria_3887.jpeg
# 6
# moved person420_bacteria_1847.jpeg
# 7
# moved person531_bacteria_2235.jpeg
# 8
# moved person537_virus_1067.jpeg
# 9
# moved person1562_bacteria_4081.jpeg
# 10
# moved person1597_bacteria_4188.jpeg
# 11
# moved person1463_bacteria_3809.jpeg
# 12

# %%
#move bacterial images
source_folder = "/content/drive/MyDrive/chest_xray 3 classes split (all)/Pneumonia/"
destination_folder = "/content/drive/MyDrive/chest_xray 3 classes split (all)/Bacterial/"

# fetch all files
for file_name in os.listdir(source_folder):
    # construct full file path
    source = source_folder + file_name
    destination = destination_folder + file_name
    # copy only files
    if 'bacteria' in file_name:
        #shutil.move(source, destination)
        print('moved', file_name)

# %%
# rename folder
#os.rename('/content/drive/MyDrive/chest_xray 3 classes split (all)/Pneumonia/', '/content/drive/MyDrive/chest_xray 3 classes split (all)/Viral/')

# %%
# 3 classes stats (init)
print(len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes split (all)/Normal')))
print(len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes split (all)/Bacterial')))
print(len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes split (all)/Viral')))
# Out:
# 1583
# 2780
# 1493
