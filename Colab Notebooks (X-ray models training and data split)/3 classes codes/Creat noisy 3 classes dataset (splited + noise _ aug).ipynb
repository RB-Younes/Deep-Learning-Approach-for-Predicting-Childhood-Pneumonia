# %%
import shutil
import os

# %%
# duplicate the dataset 
source_dir = "/content/drive/MyDrive/chest_xray 3 classes (splited .7 .15 .15)"
destination_dir = "/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)"
#shutil.copytree(source_dir, destination_dir)
# Out:
# '/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)'

# %%
# 3 classes stats (init)
print(len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/test/Normal')))
print(len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/test/Bacterial')))
print(len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/test/Viral')))

# %%
#Normal
#copy noisy images to their respective folder (Train only)
source_folder = "/content/drive/MyDrive/noise 3c chest_ray/Normal/"
destination_folder = "/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/train/Normal/"
cpt = 0
# fetch all files
for file_name in os.listdir(source_folder):
    # construct full file path
    source = source_folder + file_name
    destination = destination_folder + file_name
    # copy only files
    if os.path.isfile(source):
        cpt+=1
        #shutil.copy(source, destination)
        print('copied', file_name)
print(cpt)

# %%
#Bacterial
#copy noisy images to their respective folder (Train only)
source_folder = "/content/drive/MyDrive/noise 3c chest_ray/Bacterial/"
destination_folder = "/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/train/Bacterial/"
cpt = 0
# fetch all files
for file_name in os.listdir(source_folder):
    # construct full file path
    source = source_folder + file_name
    destination = destination_folder + file_name
    # copy only files
    if os.path.isfile(source):
        cpt+=1
        #shutil.copy(source, destination)
        print('copied', file_name)
print(cpt)

# %%
#Viral
#copy noisy images to their respective folder (Train only)
source_folder = "/content/drive/MyDrive/noise 3c chest_ray/Viral/"
destination_folder = "/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/train/Viral/"
cpt = 0
# fetch all files
for file_name in os.listdir(source_folder):
    # construct full file path
    source = source_folder + file_name
    destination = destination_folder + file_name
    # copy only files
    if os.path.isfile(source):
        cpt+=1
        #shutil.copy(source, destination)
        print('copied', file_name)
print(cpt)

# %%
from prettytable import PrettyTable
# statestics after spliting the dataset and adding noise
# stats train
num_train_normal = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/train/Normal'))
num_train_bacterial = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/train/Bacterial'))
num_train_viral = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/train/Viral'))
TOT_train = num_train_normal + num_train_bacterial + num_train_viral
# stats test
num_test_normal = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/test/Normal'))
num_test_bacterial = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/test/Bacterial'))
num_test_viral = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/test/Viral'))
TOT_test = num_test_viral + num_test_bacterial + num_test_normal
# stats valdidation
num_valid_normal = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/val/Normal'))
num_valid_bacterial = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/val/Bacterial'))
num_valid_viral = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (NOISY)(splited .7 .15 .15)/val/Viral'))
TOT_valid = num_valid_normal + num_valid_bacterial + num_valid_viral

TOT_normal =  num_valid_normal + num_test_normal + num_train_normal
TOT_viral = num_valid_viral + num_test_viral + num_train_viral
TOT_bacterial = num_train_bacterial + num_test_bacterial + num_valid_bacterial
TOT_all = TOT_normal + TOT_viral +TOT_bacterial

#table stat general
t = PrettyTable(['Class','Train','Validation', 'Test','Total'])
t.add_row(['Normal',num_train_normal,num_valid_normal,num_test_normal,TOT_normal])
t.add_row(['viral',num_train_viral,num_valid_viral,num_test_viral,TOT_viral])
t.add_row(['Bacterial',num_train_bacterial,num_valid_bacterial,num_test_bacterial,TOT_bacterial])
t.add_row(['Total',TOT_train,TOT_valid,TOT_test,TOT_all])
print(t)
# Out:
# +-----------+-------+------------+------+-------+
# |   Class   | Train | Validation | Test | Total |
# +-----------+-------+------------+------+-------+
# |   Normal  |  1329 |    237     | 238  |  1804 |
# |   viral   |  1254 |    223     | 225  |  1702 |
# | Bacterial |  2334 |    417     | 418  |  3169 |
# |   Total   |  4917 |    877     | 881  |  6675 |
# +-----------+-------+------------+------+-------+

# %%
# statestics after spliting the dataset
# stats train
num_train_normal = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (splited .7 .15 .15)/train/Normal'))
num_train_bacterial = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (splited .7 .15 .15)/train/Bacterial'))
num_train_viral = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (splited .7 .15 .15)/train/Viral'))
TOT_train = num_train_normal + num_train_bacterial + num_train_viral
# stats test
num_test_normal = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (splited .7 .15 .15)/test/Normal'))
num_test_bacterial = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (splited .7 .15 .15)/test/Bacterial'))
num_test_viral = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (splited .7 .15 .15)/test/Viral'))
TOT_test = num_test_viral + num_test_bacterial + num_test_normal
# stats valdidation
num_valid_normal = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (splited .7 .15 .15)/val/Normal'))
num_valid_bacterial = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (splited .7 .15 .15)/val/Bacterial'))
num_valid_viral = len(os.listdir('/content/drive/MyDrive/chest_xray 3 classes (splited .7 .15 .15)/val/Viral'))
TOT_valid = num_valid_normal + num_valid_bacterial + num_valid_viral

TOT_normal =  num_valid_normal + num_test_normal + num_train_normal
TOT_viral = num_valid_viral + num_test_viral + num_train_viral
TOT_bacterial = num_train_bacterial + num_test_bacterial + num_valid_bacterial
TOT_all = TOT_normal + TOT_viral +TOT_bacterial

#table stat general
t = PrettyTable(['Class','Train','Validation', 'Test','Total'])
t.add_row(['Normal',num_train_normal,num_valid_normal,num_test_normal,TOT_normal])
t.add_row(['viral',num_train_viral,num_valid_viral,num_test_viral,TOT_viral])
t.add_row(['Bacterial',num_train_bacterial,num_valid_bacterial,num_test_bacterial,TOT_bacterial])
t.add_row(['Total',TOT_train,TOT_valid,TOT_test,TOT_all])
print(t)
# Out:
# +-----------+-------+------------+------+-------+
# |   Class   | Train | Validation | Test | Total |
# +-----------+-------+------------+------+-------+
# |   Normal  |  1108 |    237     | 238  |  1583 |
# |   viral   |  1045 |    223     | 225  |  1493 |
# | Bacterial |  1945 |    417     | 418  |  2780 |
# |   Total   |  4098 |    877     | 881  |  5856 |
# +-----------+-------+------------+------+-------+
